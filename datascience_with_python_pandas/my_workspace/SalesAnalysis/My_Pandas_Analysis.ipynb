# %%
import pandas as pd

# %%
#read a sigle file

rf=pd.read_csv("./Sales_Data/Sales_April_2019.csv")
rf.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
#merging files
import os

# %%
files = [file for file in os.listdir("./Sales_Data")]
for file in files:
    print(file)
# Out:
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %%
#concatenate data frames making all 12 csv into one all_data.csv
files = [file for file in os.listdir("./Sales_Data")]

all_months_data = pd.DataFrame()
for file in files:
    df=pd.read_csv("./Sales_Data/"+file)
    all_months_data=pd.concat([all_months_data,df])
all_months_data.to_csv("all_data.csv", index=False)

# %%
#Read in updated dataframe
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# #Augment data with adiitional columns
# ### Task2:Add month column

# %%
#adding new column
all_data['Month']=3
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  month  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      3      3
# 1             NaN                                   NaN      3      3
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      3      3
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      3      3
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      3      3

# %%
#adding new column 'Month' by order date
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
"""Error is generated due to NaN"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12032/1478333128.py in <module>
#       1 #adding new column 'Month' by order date
#       2 all_data['Month'] = all_data['Order Date'].str[0:2]
# ----> 3 all_data['Month'] = all_data['Month'].astype('int32')
#       4 all_data.head()
#       5 """Error is generated due to NaN"""
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# D:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
# ...

# %% [markdown]
# ### Dropping NaN

# %%
#all NAN
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address  \
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN
#
#       month Month
# 1         3   NaN
# 356       3   NaN
# 735       3   NaN
# 1433      3   NaN
# 1553      3   NaN

# %%
#drop NAN
all_data = all_data.dropna(how= "all")#parameter how = any would drop single 
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  month Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      3    04
# 1             NaN                                   NaN      3   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      3    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      3    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      3    04

# %%
#adding new column 'Month' by order date
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
